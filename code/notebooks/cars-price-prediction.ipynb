# %%
import numpy as np
import pylab as pl
import pandas as pd
import matplotlib.pyplot as plt 
# %matplotlib inline
import seaborn as sns
from sklearn.utils import shuffle
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix,classification_report
from sklearn.preprocessing import StandardScaler, OneHotEncoder, LabelEncoder, OrdinalEncoder
from sklearn.model_selection import cross_val_score, GridSearchCV
# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os
print(os.listdir("../input"))

# Any results you write to the current directory are saved as output.
# Out:
# ['used-cars-price-prediction']

# %%
train= pd.read_csv('../input/used-cars-price-prediction/train-data.csv')
train.head()
# Out:
#    Unnamed: 0                              Name    Location  Year  \
# 0           0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1           1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2           2                      Honda Jazz V     Chennai  2011
# 3           3                 Maruti Ertiga VDI     Chennai  2012
# 4           4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage   Engine  \
# 0              72000       CNG       Manual      First  26.6 km/kg   998 CC
# 1              41000    Diesel       Manual      First  19.67 kmpl  1582 CC
# 2              46000    Petrol       Manual      First   18.2 kmpl  1199 CC
# 3              87000    Diesel       Manual      First  20.77 kmpl  1248 CC
# 4              40670    Diesel    Automatic     Second   15.2 kmpl  1968 CC
#
#        Power  Seats  New_Price  Price
# 0  58.16 bhp    5.0        NaN   1.75
# 1  126.2 bhp    5.0        NaN  12.50
# 2   88.7 bhp    5.0  8.61 Lakh   4.50
# 3  88.76 bhp    7.0        NaN   6.00
# 4  140.8 bhp    5.0        NaN  17.74

# %% [markdown]
# # Visualization

# %%
f, axes = plt.subplots(1,1, figsize = (16, 5))
g1 = sns.distplot(train["Price"], color="blue",ax = axes)
plt.title("Distributional of price")
# Out:
# Text(0.5, 1.0, 'Distributional of price')

# %%
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.graph_objs as go

ep = train['Owner_Type'].value_counts().reset_index()
ep.columns = [
    'Owner_Type', 
    'percent'
]
ep['percent'] /= len(train)

fig = px.pie(
    ep, 
    names='Owner_Type', 
    values='percent', 
    title='Countplot of Owner_Type', 
    width=800,
    height=500 
)

fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="47e95822-e38d-41be-9bc6-ae0e043072fa" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("47e95822-e38d-41be-9bc6-ae0e043072fa")) {                    Plotly.newPlot(                        "47e95822-e38d-41be-9bc6-ae0e043072fa",                        [{"domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "Owner_Type=%{label}<br>percent=%{value}<extra></extra>", "labels": ["First", "Second", "Third", "Fourth & Above"], "legendgroup": "", "name": "", "showlegend": true, "type": "pie", "values": [0.8189067951486958, 0.1608240571523509, 0.018773882704768236, 0.0014952649941850807]}],                        {"height": 500, "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": ...

# %%
cdi = train.sort_values(by='Price', ascending=False)[:100]
figure = plt.figure(figsize=(10,6))
sns.barplot(y=cdi.Name, x=cdi.Price)
plt.xticks()
plt.xlabel('Price')
plt.ylabel('Name')
plt.title('Name (Cars) by Price')
plt.show()

# %%
plt.figure(figsize=[15,4])
sns.countplot(x='Transmission', hue='Owner_Type',edgecolor="black", alpha=0.7, data=train)
sns.despine()
plt.title("Countplot of transmission by Owner_Type ")
plt.show()

# %%
sns.barplot(train["Owner_Type"],train["Kilometers_Driven"],hue= train["Transmission"],palette="spring")
plt.xticks(rotation=80)
plt.title("Transmission: Kilometers_Driven comparsion")
# Out:
# Text(0.5, 1.0, 'Transmission: Kilometers_Driven comparsion')

# %%
sns.barplot(train["Owner_Type"],train["Kilometers_Driven"],hue= train["Location"],palette="spring")
plt.xticks(rotation=80)
plt.title("Location: Kilometers_Driven comparsion")
# Out:
# Text(0.5, 1.0, 'Location: Kilometers_Driven comparsion')

# %% [markdown]
# # Owner_Type = First

# %%
display(train[train["Owner_Type"]=="First"][["Name","Location","Transmission","Year","Kilometers_Driven","Fuel_Type","Mileage","Engine","Power",
                                       "Price"]].sort_values(by="Price", ascending= False).head(10).style.background_gradient(cmap="spring"))
# Out:
# <style  type="text/css" >
# #T_b60fc6a0_771e_11eb_ab38_0242ac130202row0_col3,#T_b60fc6a0_771e_11eb_ab38_0242ac130202row4_col3{
#             background-color:  #ff807f;
#             color:  #000000;
#         }#T_b60fc6a0_771e_11eb_ab38_0242ac130202row0_col4{
#             background-color:  #ff3cc3;
#             color:  #000000;
#         }#T_b60fc6a0_771e_11eb_ab38_0242ac130202row0_col9,#T_b60fc6a0_771e_11eb_ab38_0242ac130202row2_col3,#T_b60fc6a0_771e_11eb_ab38_0242ac130202row5_col4,#T_b60fc6a0_771e_11eb_ab38_0242ac130202row6_col3,#T_b60fc6a0_771e_11eb_ab38_0242ac130202row9_col3{
#             background-color:  #ffff00;
#             color:  #000000;
#         }#T_b60fc6a0_771e_11eb_ab38_0242ac130202row1_col3,#T_b60fc6a0_771e_11eb_ab38_0242ac130202row5_col3,#T_b60fc6a0_771e_11eb_ab38_0242ac130202row6_col4,#T_b60fc6a0_771e_11eb_ab38_0242ac130202row7_col9,#T_b60fc6a0_771e_11eb_ab38_0242ac130202row8_col9,#T_b60fc6a0_771e_11eb_ab38_0242ac130202row9_col9{
#             background-color:  #ff00ff;
#             color:  #f1f1f1;
#         }#T_b60fc6a0_771e_11eb_ab38_0242ac130202row1_col4{
#             background-color:  #ff0ef1;
#             color:  #f1f1f1;
#         }#T_b60fc6a0_771e_11eb_ab38_0242ac130202row1_col9{
#             background-color:  #ff42bd;
#             color:  #000000;
#         }#T_b60fc6a0_771e_11eb_ab38_0242ac130202row2_col4{
#             background-color:  #ff3fc0;
#             color:  #000000;
#         }#T_b60fc6a0_771e_11eb_ab38_0242ac130202row2_col9{
#             background-color:  #ff39c6;
#             color:  #000000;
#         }#T_b60fc6a0_771e_11eb_ab38_0242ac130202row3_col3,#T_b60fc6a0_771e_11eb_ab38_0242ac130202row7_col3{
#             background-color:  #ffc03f;
#             color:  #000000;
#         }#T_b60fc6a0_771e_11eb_ab38_0242ac130202row3_col4{
#             background-color:  #ff45ba;
#             color:  #000000;
#         }#T_b60fc6a0_771e_11eb_ab38_0242ac130202row3_col9{
#             background-color:  #ff2ed1;
#             color:  #f1f1f1;
#         }#T_b60fc6a0_771e_11eb_ab38_0242ac130202row4_col4{
#             background-color:  #ff28d7;
#             color:  #f1f1f1;
#         }#T_b60fc6a0_771e_11eb_ab38_0242ac130202row4_col9{
#             background-color:  #ff2cd3;
#             color:  #f1f1f1;
#         }#T_b60fc6a0_771e_11eb_ab38_0242ac130202row5_col9{
#             background-color:  #ff13ec;
#             color:  #f1f1f1;
#         }#T_b60fc6a0_771e_11eb_ab38_0242ac130202row6_col9{
#             background-color:  #ff10ef;
#             color:  #f1f1f1;
#         }#T_b60fc6a0_771e_11eb_ab38_0242ac130202row7_col4{
#             background-color:  #ff09f6;
#             color:  #f1f1f1;
#         }#T_b60fc6a0_771e_11eb_ab38_0242ac130202row8_col3{
#             background-color:  #ff40bf;
#             color:  #000000;
#         }#T_b60fc6a0_771e_11eb_ab38_0242ac130202row8_col4{
#             background-color:  #ff19e6;
#             color:  #f1f1f1;
#         }#T_b60fc6a0_771e_11eb_ab38_0242ac130202row9_col4{
#             background-color:  #ff12ed;
#             color:  #f1f1f1;
#         }</style><table id="T_b60fc6a0_771e_11eb_ab38_0242ac130202" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Name</th>        <th class="col_heading level0 col1" >Location</th>        <th class="col_heading level0 col2" >Transmission</th>        <th class="col_heading level0 col3" >Year</th>        <th class="col_heading level0 col4" >Kilometers_Driven</th>        <th class="col_heading level0 col5" >Fuel_Type</th>        <th class="col_heading level0 col6" >Mileage</th>        <th class="col_heading level0 col7" >Engine</th>        <th class="col_heading level0 col8" >Power</th>        <th class="col_heading level0 col9" >Price</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b60fc6a0_771e_11eb_ab38_0242ac130202level0_row0" class="row_heading level0 row0" >4079</th>
#                         <td id="T_b60fc6a0_771e_11eb_ab38_0242ac130202row0_col0" class="data row0 col0" >Land Rover Range Rover 3.0 Diesel LWB Vogue</td>
#                         <td id="T_b60fc6a0_771e_11eb_ab38_0242ac130202row0_col1" class="data row0 col1" >Hyderabad</td>
#                         <td id="T_b60fc6a0_771e_11eb_ab38_0242ac130202row0_col2" class="data row0 col2" >Automatic</td>
#                         <td id="T_b60fc6a0_771e_11eb_ab38_0242ac130202row0_col3" class="data row0 col3" >2017</td>
#                         <td id="T_b60fc6a0_771e_11eb_ab38_0242ac130202row0_col4" class="data row0 col4" >25000</td>
#                         <td id="T_b60fc6a0_771e_11eb_ab38_0242ac130202row0_col5" class="data row0 col5" >Diesel</td>
#                         <td id="T_b60fc6a0_771e_11eb_ab38_0242ac130202row0_col6" class="data row0 col6" >13.33 kmpl</td>
#                         <td id="T_b60fc6a0_771e_11eb_ab38_0242ac130202row0_col7" class="data row0 col7" >2993 CC</td>
#                         <td id="T_b60fc6a0_771e_11eb_ab38_0242ac130202row0_col8" class="data row0 col8" >255 bhp</td>
#                         <td id="T_b60fc6a0_771e_11eb_ab38_0242ac130202row0_col9" class="data row0 col9" >160.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_b60fc6a0_771e_11eb_ab38_0242ac130202level0_row1" class="row_heading level0 row1" >5919</th>
#                         <td id="T_b60fc6a0_771e_11eb_ab38_0242ac130202row1_col0" class="data row1 col0" >Jaguar F Type 5.0 V8 S</td>
#                         <td id="T_b60fc6a0_771e_11eb_ab38_0242ac130202row1_col1" class="data row1 col1" >Hyderabad</td>
#                         <td id="T_b60fc6a0_771e_11eb_ab38_0242ac130202row1_col2" class="data row1 col2" >Automatic</td>
#                         <td id="T_b60fc6a0_771e_11eb_ab38_0242ac130202row1_col3" class="data row1 col3" >2015</td>
#                         <td id="T_b60fc6a0_771e_11eb_ab38_0242ac130202row1_col4" class="data row1 col4" >8000</td>
#                         <td id="T_b60fc6a0_771e_11eb_ab38_0242ac130202row1_col5" class="data row1 col5" >Petrol</td>
#                         <td id="T_b60fc6a0_771e_11eb_ab38_0242ac130202row1_col6" class="data row1 col6" >12.5 kmpl</td>
#                         <td id="T_b60fc6a0_771e_11eb_ab38_0242ac130202row1_col7" class="data row1 col7" >5000 CC</td>
#                         <td id="T_b60fc6a0_771e_11eb_ab38_0242ac130202row1_col8" class="data row1 col8" >488.1 bhp</td>
#                         <td id="T_b60fc6a0_771e_11eb_ab38_0242ac130202row1_col9" class="data row1 col9" >100.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_b60fc6a0_771e_11eb_ab38_0242ac130202level0_row2" class="row_heading level0 row2" >1505</th>
#                         <td id="T_b60fc6a0_771e_11eb_ab38_0242ac130202row2_col0" class="data row2 col0" >Land Rover Range Rover Sport SE</td>
#                         <td id="T_b60fc6a0_771e_11eb_ab38_0242ac130202row2_col1" class="data row2 col1" >Kochi</td>
#                         <td id="T_b60fc6a0_771e_11eb_ab38_0242ac130202row2_col2" class="data row2 col2" >Automatic</td>
#                         <td id="T_b60fc6a0_771e_11eb_ab38_0242ac130202row2_col3" class="data row2 col3" >2019</td>
#                         <td id="T_b60fc6a0_771e_11eb_ab38_0242ac130202row2_col4" class="data row2 col4" >26013</td>
#                         <td id="T_b60fc6a0_771e_11eb_ab38_0242ac130202row2_col5" class="data row2 col5" >Diesel</td>
#                         <td id="T_b60fc6a0_771e_11eb_ab38_0242ac130202row2_col6" class="data row2 col6" >12.65 kmpl</td>
#                         <td id="T_b60fc6a0_771e_11eb_ab38_0242ac130202row2_col7" class="data row2 col7" >2993 CC</td>
#                         <td id="T_b60fc6a0_771e_11eb_ab38_0242ac130202row2_col8" class="data row2 col8" >255 bhp</td>
#                         <td id="T_b60fc6a0_771e_11eb_ab38_0242ac130202row2_col9" class="data row2 col9" >97.070000</td>
#             </tr>
#             <tr>
#                         <th id="T_b60fc6a0_771e_11eb_ab38_0242ac130202level0_row3" class="row_heading level0 row3" >1974</th>
#                         <td id="T_b

# %% [markdown]
# # Owner_Type = Second

# %%
display(train[train["Owner_Type"]=="Second"][["Name","Location","Transmission","Year","Kilometers_Driven","Fuel_Type","Mileage","Engine","Power",
                                       "Price"]].sort_values(by="Price", ascending= False).head(10).style.background_gradient(cmap="spring"))
# Out:
# <style  type="text/css" >
# #T_b632bfac_771e_11eb_ab38_0242ac130202row0_col3,#T_b632bfac_771e_11eb_ab38_0242ac130202row4_col3{
#             background-color:  #ff6699;
#             color:  #000000;
#         }#T_b632bfac_771e_11eb_ab38_0242ac130202row0_col4,#T_b632bfac_771e_11eb_ab38_0242ac130202row3_col3,#T_b632bfac_771e_11eb_ab38_0242ac130202row9_col9{
#             background-color:  #ff00ff;
#             color:  #f1f1f1;
#         }#T_b632bfac_771e_11eb_ab38_0242ac130202row0_col9,#T_b632bfac_771e_11eb_ab38_0242ac130202row2_col4,#T_b632bfac_771e_11eb_ab38_0242ac130202row5_col3{
#             background-color:  #ffff00;
#             color:  #000000;
#         }#T_b632bfac_771e_11eb_ab38_0242ac130202row1_col3,#T_b632bfac_771e_11eb_ab38_0242ac130202row2_col3,#T_b632bfac_771e_11eb_ab38_0242ac130202row8_col3{
#             background-color:  #ff33cc;
#             color:  #000000;
#         }#T_b632bfac_771e_11eb_ab38_0242ac130202row1_col4{
#             background-color:  #ff3bc4;
#             color:  #000000;
#         }#T_b632bfac_771e_11eb_ab38_0242ac130202row1_col9{
#             background-color:  #ffa05f;
#             color:  #000000;
#         }#T_b632bfac_771e_11eb_ab38_0242ac130202row2_col9{
#             background-color:  #ff659a;
#             color:  #000000;
#         }#T_b632bfac_771e_11eb_ab38_0242ac130202row3_col4{
#             background-color:  #ffd22d;
#             color:  #000000;
#         }#T_b632bfac_771e_11eb_ab38_0242ac130202row3_col9{
#             background-color:  #ff609f;
#             color:  #000000;
#         }#T_b632bfac_771e_11eb_ab38_0242ac130202row4_col4{
#             background-color:  #ff9a65;
#             color:  #000000;
#         }#T_b632bfac_771e_11eb_ab38_0242ac130202row4_col9{
#             background-color:  #ff5fa0;
#             color:  #000000;
#         }#T_b632bfac_771e_11eb_ab38_0242ac130202row5_col4,#T_b632bfac_771e_11eb_ab38_0242ac130202row7_col4{
#             background-color:  #ff3fc0;
#             color:  #000000;
#         }#T_b632bfac_771e_11eb_ab38_0242ac130202row5_col9{
#             background-color:  #ff21de;
#             color:  #f1f1f1;
#         }#T_b632bfac_771e_11eb_ab38_0242ac130202row6_col3,#T_b632bfac_771e_11eb_ab38_0242ac130202row9_col3{
#             background-color:  #ffcc33;
#             color:  #000000;
#         }#T_b632bfac_771e_11eb_ab38_0242ac130202row6_col4{
#             background-color:  #ff5aa5;
#             color:  #000000;
#         }#T_b632bfac_771e_11eb_ab38_0242ac130202row6_col9{
#             background-color:  #ff15ea;
#             color:  #f1f1f1;
#         }#T_b632bfac_771e_11eb_ab38_0242ac130202row7_col3{
#             background-color:  #ff9966;
#             color:  #000000;
#         }#T_b632bfac_771e_11eb_ab38_0242ac130202row7_col9{
#             background-color:  #ff11ee;
#             color:  #f1f1f1;
#         }#T_b632bfac_771e_11eb_ab38_0242ac130202row8_col4{
#             background-color:  #ff9d62;
#             color:  #000000;
#         }#T_b632bfac_771e_11eb_ab38_0242ac130202row8_col9{
#             background-color:  #ff04fb;
#             color:  #f1f1f1;
#         }#T_b632bfac_771e_11eb_ab38_0242ac130202row9_col4{
#             background-color:  #ff629d;
#             color:  #000000;
#         }</style><table id="T_b632bfac_771e_11eb_ab38_0242ac130202" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Name</th>        <th class="col_heading level0 col1" >Location</th>        <th class="col_heading level0 col2" >Transmission</th>        <th class="col_heading level0 col3" >Year</th>        <th class="col_heading level0 col4" >Kilometers_Driven</th>        <th class="col_heading level0 col5" >Fuel_Type</th>        <th class="col_heading level0 col6" >Mileage</th>        <th class="col_heading level0 col7" >Engine</th>        <th class="col_heading level0 col8" >Power</th>        <th class="col_heading level0 col9" >Price</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b632bfac_771e_11eb_ab38_0242ac130202level0_row0" class="row_heading level0 row0" >4691</th>
#                         <td id="T_b632bfac_771e_11eb_ab38_0242ac130202row0_col0" class="data row0 col0" >Mercedes-Benz SLK-Class 55 AMG</td>
#                         <td id="T_b632bfac_771e_11eb_ab38_0242ac130202row0_col1" class="data row0 col1" >Bangalore</td>
#                         <td id="T_b632bfac_771e_11eb_ab38_0242ac130202row0_col2" class="data row0 col2" >Automatic</td>
#                         <td id="T_b632bfac_771e_11eb_ab38_0242ac130202row0_col3" class="data row0 col3" >2014</td>
#                         <td id="T_b632bfac_771e_11eb_ab38_0242ac130202row0_col4" class="data row0 col4" >3000</td>
#                         <td id="T_b632bfac_771e_11eb_ab38_0242ac130202row0_col5" class="data row0 col5" >Petrol</td>
#                         <td id="T_b632bfac_771e_11eb_ab38_0242ac130202row0_col6" class="data row0 col6" >12.0 kmpl</td>
#                         <td id="T_b632bfac_771e_11eb_ab38_0242ac130202row0_col7" class="data row0 col7" >5461 CC</td>
#                         <td id="T_b632bfac_771e_11eb_ab38_0242ac130202row0_col8" class="data row0 col8" >421 bhp</td>
#                         <td id="T_b632bfac_771e_11eb_ab38_0242ac130202row0_col9" class="data row0 col9" >90.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_b632bfac_771e_11eb_ab38_0242ac130202level0_row1" class="row_heading level0 row1" >3489</th>
#                         <td id="T_b632bfac_771e_11eb_ab38_0242ac130202row1_col0" class="data row1 col0" >Porsche Panamera Diesel</td>
#                         <td id="T_b632bfac_771e_11eb_ab38_0242ac130202row1_col1" class="data row1 col1" >Bangalore</td>
#                         <td id="T_b632bfac_771e_11eb_ab38_0242ac130202row1_col2" class="data row1 col2" >Automatic</td>
#                         <td id="T_b632bfac_771e_11eb_ab38_0242ac130202row1_col3" class="data row1 col3" >2013</td>
#                         <td id="T_b632bfac_771e_11eb_ab38_0242ac130202row1_col4" class="data row1 col4" >19828</td>
#                         <td id="T_b632bfac_771e_11eb_ab38_0242ac130202row1_col5" class="data row1 col5" >Diesel</td>
#                         <td id="T_b632bfac_771e_11eb_ab38_0242ac130202row1_col6" class="data row1 col6" >17.85 kmpl</td>
#                         <td id="T_b632bfac_771e_11eb_ab38_0242ac130202row1_col7" class="data row1 col7" >2967 CC</td>
#                         <td id="T_b632bfac_771e_11eb_ab38_0242ac130202row1_col8" class="data row1 col8" >300 bhp</td>
#                         <td id="T_b632bfac_771e_11eb_ab38_0242ac130202row1_col9" class="data row1 col9" >75.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_b632bfac_771e_11eb_ab38_0242ac130202level0_row2" class="row_heading level0 row2" >5416</th>
#                         <td id="T_b632bfac_771e_11eb_ab38_0242ac130202row2_col0" class="data row2 col0" >Land Rover Range Rover Vogue SE 4.4 SDV8</td>
#                         <td id="T_b632bfac_771e_11eb_ab38_0242ac130202row2_col1" class="data row2 col1" >Coimbatore</td>
#                         <td id="T_b632bfac_771e_11eb_ab38_0242ac130202row2_col2" class="data row2 col2" >Automatic</td>
#                         <td id="T_b632bfac_771e_11eb_ab38_0242ac130202row2_col3" class="data row2 col3" >2013</td>
#                         <td id="T_b632bfac_771e_11eb_ab38_0242ac130202row2_col4" class="data row2 col4" >75995</td>
#                         <td id="T_b632bfac_771e_11eb_ab38_0242ac130202row2_col5" class="data row2 col5" >Diesel</td>
#                         <td id="T_b632bfac_771e_11eb_ab38_0242ac130202row2_col6" class="data row2 col6" >11.49 kmpl</td>
#                         <td id="T_b632bfac_771e_11eb_ab38_0242ac130202row2_col7" class="data row2 col7" >4367 CC</td>
#                         <td id="T_b632bfac_771e_11eb_ab38_0242ac130202row2_col8" class="data row2 col8" >335.3 bhp</td>
#                         <td id="T_b632bfac_771e_11eb_ab38_0242ac130202row2_col9" class="data row2 col9" >65.810000</td>
#             </tr>
#             <tr>

# %% [markdown]
# # Owner_Type = Third

# %%
display(train[train["Owner_Type"]=="Third"][["Name","Location","Transmission","Year","Kilometers_Driven","Fuel_Type","Mileage","Engine","Power",
                                       "Price"]].sort_values(by="Price", ascending= False).head(10).style.background_gradient(cmap="spring"))
# Out:
# <style  type="text/css" >
# #T_b6558078_771e_11eb_ab38_0242ac130202row0_col3,#T_b6558078_771e_11eb_ab38_0242ac130202row2_col3{
#             background-color:  #ffc03f;
#             color:  #000000;
#         }#T_b6558078_771e_11eb_ab38_0242ac130202row0_col4,#T_b6558078_771e_11eb_ab38_0242ac130202row6_col3,#T_b6558078_771e_11eb_ab38_0242ac130202row8_col9,#T_b6558078_771e_11eb_ab38_0242ac130202row9_col9{
#             background-color:  #ff00ff;
#             color:  #f1f1f1;
#         }#T_b6558078_771e_11eb_ab38_0242ac130202row0_col9,#T_b6558078_771e_11eb_ab38_0242ac130202row3_col3,#T_b6558078_771e_11eb_ab38_0242ac130202row4_col3,#T_b6558078_771e_11eb_ab38_0242ac130202row5_col3,#T_b6558078_771e_11eb_ab38_0242ac130202row7_col4,#T_b6558078_771e_11eb_ab38_0242ac130202row8_col3,#T_b6558078_771e_11eb_ab38_0242ac130202row9_col3{
#             background-color:  #ffff00;
#             color:  #000000;
#         }#T_b6558078_771e_11eb_ab38_0242ac130202row1_col3,#T_b6558078_771e_11eb_ab38_0242ac130202row7_col3{
#             background-color:  #ff807f;
#             color:  #000000;
#         }#T_b6558078_771e_11eb_ab38_0242ac130202row1_col4{
#             background-color:  #ff38c7;
#             color:  #000000;
#         }#T_b6558078_771e_11eb_ab38_0242ac130202row1_col9{
#             background-color:  #ff4cb3;
#             color:  #000000;
#         }#T_b6558078_771e_11eb_ab38_0242ac130202row2_col4{
#             background-color:  #ff44bb;
#             color:  #000000;
#         }#T_b6558078_771e_11eb_ab38_0242ac130202row2_col9{
#             background-color:  #ff19e6;
#             color:  #f1f1f1;
#         }#T_b6558078_771e_11eb_ab38_0242ac130202row3_col4{
#             background-color:  #ff926d;
#             color:  #000000;
#         }#T_b6558078_771e_11eb_ab38_0242ac130202row3_col9{
#             background-color:  #ff0df2;
#             color:  #f1f1f1;
#         }#T_b6558078_771e_11eb_ab38_0242ac130202row4_col4{
#             background-color:  #ff2fd0;
#             color:  #f1f1f1;
#         }#T_b6558078_771e_11eb_ab38_0242ac130202row4_col9{
#             background-color:  #ff0bf4;
#             color:  #f1f1f1;
#         }#T_b6558078_771e_11eb_ab38_0242ac130202row5_col4{
#             background-color:  #ff6699;
#             color:  #000000;
#         }#T_b6558078_771e_11eb_ab38_0242ac130202row5_col9{
#             background-color:  #ff08f7;
#             color:  #f1f1f1;
#         }#T_b6558078_771e_11eb_ab38_0242ac130202row6_col4{
#             background-color:  #ff906f;
#             color:  #000000;
#         }#T_b6558078_771e_11eb_ab38_0242ac130202row6_col9{
#             background-color:  #ff06f9;
#             color:  #f1f1f1;
#         }#T_b6558078_771e_11eb_ab38_0242ac130202row7_col9{
#             background-color:  #ff04fb;
#             color:  #f1f1f1;
#         }#T_b6558078_771e_11eb_ab38_0242ac130202row8_col4{
#             background-color:  #ffa956;
#             color:  #000000;
#         }#T_b6558078_771e_11eb_ab38_0242ac130202row9_col4{
#             background-color:  #ff7a85;
#             color:  #000000;
#         }</style><table id="T_b6558078_771e_11eb_ab38_0242ac130202" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Name</th>        <th class="col_heading level0 col1" >Location</th>        <th class="col_heading level0 col2" >Transmission</th>        <th class="col_heading level0 col3" >Year</th>        <th class="col_heading level0 col4" >Kilometers_Driven</th>        <th class="col_heading level0 col5" >Fuel_Type</th>        <th class="col_heading level0 col6" >Mileage</th>        <th class="col_heading level0 col7" >Engine</th>        <th class="col_heading level0 col8" >Power</th>        <th class="col_heading level0 col9" >Price</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b6558078_771e_11eb_ab38_0242ac130202level0_row0" class="row_heading level0 row0" >5781</th>
#                         <td id="T_b6558078_771e_11eb_ab38_0242ac130202row0_col0" class="data row0 col0" >Lamborghini Gallardo Coupe</td>
#                         <td id="T_b6558078_771e_11eb_ab38_0242ac130202row0_col1" class="data row0 col1" >Delhi</td>
#                         <td id="T_b6558078_771e_11eb_ab38_0242ac130202row0_col2" class="data row0 col2" >Automatic</td>
#                         <td id="T_b6558078_771e_11eb_ab38_0242ac130202row0_col3" class="data row0 col3" >2011</td>
#                         <td id="T_b6558078_771e_11eb_ab38_0242ac130202row0_col4" class="data row0 col4" >6500</td>
#                         <td id="T_b6558078_771e_11eb_ab38_0242ac130202row0_col5" class="data row0 col5" >Petrol</td>
#                         <td id="T_b6558078_771e_11eb_ab38_0242ac130202row0_col6" class="data row0 col6" >6.4 kmpl</td>
#                         <td id="T_b6558078_771e_11eb_ab38_0242ac130202row0_col7" class="data row0 col7" >5204 CC</td>
#                         <td id="T_b6558078_771e_11eb_ab38_0242ac130202row0_col8" class="data row0 col8" >560 bhp</td>
#                         <td id="T_b6558078_771e_11eb_ab38_0242ac130202row0_col9" class="data row0 col9" >120.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_b6558078_771e_11eb_ab38_0242ac130202level0_row1" class="row_heading level0 row1" >2978</th>
#                         <td id="T_b6558078_771e_11eb_ab38_0242ac130202row1_col0" class="data row1 col0" >Porsche Panamera 2010 2013 4S</td>
#                         <td id="T_b6558078_771e_11eb_ab38_0242ac130202row1_col1" class="data row1 col1" >Coimbatore</td>
#                         <td id="T_b6558078_771e_11eb_ab38_0242ac130202row1_col2" class="data row1 col2" >Automatic</td>
#                         <td id="T_b6558078_771e_11eb_ab38_0242ac130202row1_col3" class="data row1 col3" >2010</td>
#                         <td id="T_b6558078_771e_11eb_ab38_0242ac130202row1_col4" class="data row1 col4" >42400</td>
#                         <td id="T_b6558078_771e_11eb_ab38_0242ac130202row1_col5" class="data row1 col5" >Petrol</td>
#                         <td id="T_b6558078_771e_11eb_ab38_0242ac130202row1_col6" class="data row1 col6" >8.0 kmpl</td>
#                         <td id="T_b6558078_771e_11eb_ab38_0242ac130202row1_col7" class="data row1 col7" >4806 CC</td>
#                         <td id="T_b6558078_771e_11eb_ab38_0242ac130202row1_col8" class="data row1 col8" >394.3 bhp</td>
#                         <td id="T_b6558078_771e_11eb_ab38_0242ac130202row1_col9" class="data row1 col9" >42.910000</td>
#             </tr>
#             <tr>
#                         <th id="T_b6558078_771e_11eb_ab38_0242ac130202level0_row2" class="row_heading level0 row2" >2288</th>
#                         <td id="T_b6558078_771e_11eb_ab38_0242ac130202row2_col0" class="data row2 col0" >Audi A6 3.0 TDI quattro</td>
#                         <td id="T_b6558078_771e_11eb_ab38_0242ac130202row2_col1" class="data row2 col1" >Bangalore</td>
#                         <td id="T_b6558078_771e_11eb_ab38_0242ac130202row2_col2" class="data row2 col2" >Automatic</td>
#                         <td id="T_b6558078_771e_11eb_ab38_0242ac130202row2_col3" class="data row2 col3" >2011</td>
#                         <td id="T_b6558078_771e_11eb_ab38_0242ac130202row2_col4" class="data row2 col4" >50000</td>
#                         <td id="T_b6558078_771e_11eb_ab38_0242ac130202row2_col5" class="data row2 col5" >Diesel</td>
#                         <td id="T_b6558078_771e_11eb_ab38_0242ac130202row2_col6" class="data row2 col6" >16.77 kmpl</td>
#                         <td id="T_b6558078_771e_11eb_ab38_0242ac130202row2_col7" class="data row2 col7" >2967 CC</td>
#                         <td id="T_b6558078_771e_11eb_ab38_0242ac130202row2_col8" class="data row2 col8" >241.38 bhp</td>
#                         <td id="T_b6558078_771e_11eb_ab38_0242ac130202row2_col9" class="data row2 col9" >21.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_b6558078_771e_11eb_ab38_0242ac130202level0_row3" class="row_heading level0 row3" >3955</th>
#                         <td id="T_b6558078_771e_11eb_

# %% [markdown]
# # Owner_Type =Fourth & Above

# %%
display(train[train["Owner_Type"]=="Fourth & Above"][["Name","Location","Transmission","Year","Kilometers_Driven","Fuel_Type","Mileage","Engine","Power",
                                       "Price"]].sort_values(by="Price", ascending= False).head(10).style.background_gradient(cmap="spring"))
# Out:
# <style  type="text/css" >
# #T_b684cd74_771e_11eb_ab38_0242ac130202row0_col3,#T_b684cd74_771e_11eb_ab38_0242ac130202row8_col3{
#             background-color:  #ffc738;
#             color:  #000000;
#         }#T_b684cd74_771e_11eb_ab38_0242ac130202row0_col4{
#             background-color:  #ff15ea;
#             color:  #f1f1f1;
#         }#T_b684cd74_771e_11eb_ab38_0242ac130202row0_col9,#T_b684cd74_771e_11eb_ab38_0242ac130202row2_col4,#T_b684cd74_771e_11eb_ab38_0242ac130202row3_col3{
#             background-color:  #ffff00;
#             color:  #000000;
#         }#T_b684cd74_771e_11eb_ab38_0242ac130202row1_col3{
#             background-color:  #ff718e;
#             color:  #000000;
#         }#T_b684cd74_771e_11eb_ab38_0242ac130202row1_col4{
#             background-color:  #ffe41b;
#             color:  #000000;
#         }#T_b684cd74_771e_11eb_ab38_0242ac130202row1_col9{
#             background-color:  #ffe21d;
#             color:  #000000;
#         }#T_b684cd74_771e_11eb_ab38_0242ac130202row2_col3,#T_b684cd74_771e_11eb_ab38_0242ac130202row4_col3{
#             background-color:  #ffaa55;
#             color:  #000000;
#         }#T_b684cd74_771e_11eb_ab38_0242ac130202row2_col9{
#             background-color:  #ff936c;
#             color:  #000000;
#         }#T_b684cd74_771e_11eb_ab38_0242ac130202row3_col4{
#             background-color:  #ff01fe;
#             color:  #f1f1f1;
#         }#T_b684cd74_771e_11eb_ab38_0242ac130202row3_col9{
#             background-color:  #ff5ca3;
#             color:  #000000;
#         }#T_b684cd74_771e_11eb_ab38_0242ac130202row4_col4{
#             background-color:  #ff26d9;
#             color:  #f1f1f1;
#         }#T_b684cd74_771e_11eb_ab38_0242ac130202row4_col9{
#             background-color:  #ff4ab5;
#             color:  #000000;
#         }#T_b684cd74_771e_11eb_ab38_0242ac130202row5_col3{
#             background-color:  #ff8e71;
#             color:  #000000;
#         }#T_b684cd74_771e_11eb_ab38_0242ac130202row5_col4{
#             background-color:  #ff52ad;
#             color:  #000000;
#         }#T_b684cd74_771e_11eb_ab38_0242ac130202row5_col9{
#             background-color:  #ff1be4;
#             color:  #f1f1f1;
#         }#T_b684cd74_771e_11eb_ab38_0242ac130202row6_col3,#T_b684cd74_771e_11eb_ab38_0242ac130202row8_col4,#T_b684cd74_771e_11eb_ab38_0242ac130202row8_col9{
#             background-color:  #ff00ff;
#             color:  #f1f1f1;
#         }#T_b684cd74_771e_11eb_ab38_0242ac130202row6_col4{
#             background-color:  #ffd32c;
#             color:  #000000;
#         }#T_b684cd74_771e_11eb_ab38_0242ac130202row6_col9{
#             background-color:  #ff10ef;
#             color:  #f1f1f1;
#         }#T_b684cd74_771e_11eb_ab38_0242ac130202row7_col3{
#             background-color:  #ffe31c;
#             color:  #000000;
#         }#T_b684cd74_771e_11eb_ab38_0242ac130202row7_col4{
#             background-color:  #ff19e6;
#             color:  #f1f1f1;
#         }#T_b684cd74_771e_11eb_ab38_0242ac130202row7_col9{
#             background-color:  #ff0df2;
#             color:  #f1f1f1;
#         }</style><table id="T_b684cd74_771e_11eb_ab38_0242ac130202" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Name</th>        <th class="col_heading level0 col1" >Location</th>        <th class="col_heading level0 col2" >Transmission</th>        <th class="col_heading level0 col3" >Year</th>        <th class="col_heading level0 col4" >Kilometers_Driven</th>        <th class="col_heading level0 col5" >Fuel_Type</th>        <th class="col_heading level0 col6" >Mileage</th>        <th class="col_heading level0 col7" >Engine</th>        <th class="col_heading level0 col8" >Power</th>        <th class="col_heading level0 col9" >Price</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b684cd74_771e_11eb_ab38_0242ac130202level0_row0" class="row_heading level0 row0" >885</th>
#                         <td id="T_b684cd74_771e_11eb_ab38_0242ac130202row0_col0" class="data row0 col0" >Maruti Grand Vitara AT</td>
#                         <td id="T_b684cd74_771e_11eb_ab38_0242ac130202row0_col1" class="data row0 col1" >Chennai</td>
#                         <td id="T_b684cd74_771e_11eb_ab38_0242ac130202row0_col2" class="data row0 col2" >Automatic</td>
#                         <td id="T_b684cd74_771e_11eb_ab38_0242ac130202row0_col3" class="data row0 col3" >2008</td>
#                         <td id="T_b684cd74_771e_11eb_ab38_0242ac130202row0_col4" class="data row0 col4" >77000</td>
#                         <td id="T_b684cd74_771e_11eb_ab38_0242ac130202row0_col5" class="data row0 col5" >Petrol</td>
#                         <td id="T_b684cd74_771e_11eb_ab38_0242ac130202row0_col6" class="data row0 col6" >9.7 kmpl</td>
#                         <td id="T_b684cd74_771e_11eb_ab38_0242ac130202row0_col7" class="data row0 col7" >1995 CC</td>
#                         <td id="T_b684cd74_771e_11eb_ab38_0242ac130202row0_col8" class="data row0 col8" >163.5 bhp</td>
#                         <td id="T_b684cd74_771e_11eb_ab38_0242ac130202row0_col9" class="data row0 col9" >5.500000</td>
#             </tr>
#             <tr>
#                         <th id="T_b684cd74_771e_11eb_ab38_0242ac130202level0_row1" class="row_heading level0 row1" >2988</th>
#                         <td id="T_b684cd74_771e_11eb_ab38_0242ac130202row1_col0" class="data row1 col0" >Toyota Innova 2.5 G4 Diesel 8-seater</td>
#                         <td id="T_b684cd74_771e_11eb_ab38_0242ac130202row1_col1" class="data row1 col1" >Chennai</td>
#                         <td id="T_b684cd74_771e_11eb_ab38_0242ac130202row1_col2" class="data row1 col2" >Manual</td>
#                         <td id="T_b684cd74_771e_11eb_ab38_0242ac130202row1_col3" class="data row1 col3" >2005</td>
#                         <td id="T_b684cd74_771e_11eb_ab38_0242ac130202row1_col4" class="data row1 col4" >240000</td>
#                         <td id="T_b684cd74_771e_11eb_ab38_0242ac130202row1_col5" class="data row1 col5" >Diesel</td>
#                         <td id="T_b684cd74_771e_11eb_ab38_0242ac130202row1_col6" class="data row1 col6" >12.8 kmpl</td>
#                         <td id="T_b684cd74_771e_11eb_ab38_0242ac130202row1_col7" class="data row1 col7" >2494 CC</td>
#                         <td id="T_b684cd74_771e_11eb_ab38_0242ac130202row1_col8" class="data row1 col8" >102 bhp</td>
#                         <td id="T_b684cd74_771e_11eb_ab38_0242ac130202row1_col9" class="data row1 col9" >5.100000</td>
#             </tr>
#             <tr>
#                         <th id="T_b684cd74_771e_11eb_ab38_0242ac130202level0_row2" class="row_heading level0 row2" >29</th>
#                         <td id="T_b684cd74_771e_11eb_ab38_0242ac130202row2_col0" class="data row2 col0" >Toyota Innova 2.5 V Diesel 7-seater</td>
#                         <td id="T_b684cd74_771e_11eb_ab38_0242ac130202row2_col1" class="data row2 col1" >Mumbai</td>
#                         <td id="T_b684cd74_771e_11eb_ab38_0242ac130202row2_col2" class="data row2 col2" >Manual</td>
#                         <td id="T_b684cd74_771e_11eb_ab38_0242ac130202row2_col3" class="data row2 col3" >2007</td>
#                         <td id="T_b684cd74_771e_11eb_ab38_0242ac130202row2_col4" class="data row2 col4" >262000</td>
#                         <td id="T_b684cd74_771e_11eb_ab38_0242ac130202row2_col5" class="data row2 col5" >Diesel</td>
#                         <td id="T_b684cd74_771e_11eb_ab38_0242ac130202row2_col6" class="data row2 col6" >12.8 kmpl</td>
#                         <td id="T_b684cd74_771e_11eb_ab38_0242ac130202row2_col7" class="data row2 col7" >2494 CC</td>
#                         <td id="T_b684cd74_771e_11eb_ab38_0242ac130202row2_col8" class="data row2 col8" >102 bhp</td>
#                         <td id="T_b684cd74_771e_11eb_ab38_0242ac130202row2_col9" class="data row2 col9" >4.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_b684cd74_771e_11eb_ab38_0242ac130202level0_row3" class="row_heading level0 row3" >1081</th>
#                         <td id="T_b684cd74_7

# %% [markdown]
# # Transmission : Automatic

# %%
display(train[train["Transmission"]=="Automatic"][["Name","Location","Transmission","Year","Kilometers_Driven","Fuel_Type","Mileage","Engine","Power",
                                       "Price"]].sort_values(by="Price", ascending= False).head(30).style.background_gradient(cmap="spring"))
# Out:
# <style  type="text/css" >
# #T_b6b61cbc_771e_11eb_ab38_0242ac130202row0_col3,#T_b6b61cbc_771e_11eb_ab38_0242ac130202row5_col3,#T_b6b61cbc_771e_11eb_ab38_0242ac130202row15_col3,#T_b6b61cbc_771e_11eb_ab38_0242ac130202row23_col3,#T_b6b61cbc_771e_11eb_ab38_0242ac130202row25_col3,#T_b6b61cbc_771e_11eb_ab38_0242ac130202row27_col3{
#             background-color:  #ffc03f;
#             color:  #000000;
#         }#T_b6b61cbc_771e_11eb_ab38_0242ac130202row0_col4{
#             background-color:  #ff3cc3;
#             color:  #000000;
#         }#T_b6b61cbc_771e_11eb_ab38_0242ac130202row0_col9,#T_b6b61cbc_771e_11eb_ab38_0242ac130202row3_col3,#T_b6b61cbc_771e_11eb_ab38_0242ac130202row7_col4,#T_b6b61cbc_771e_11eb_ab38_0242ac130202row8_col3,#T_b6b61cbc_771e_11eb_ab38_0242ac130202row11_col3,#T_b6b61cbc_771e_11eb_ab38_0242ac130202row16_col3{
#             background-color:  #ffff00;
#             color:  #000000;
#         }#T_b6b61cbc_771e_11eb_ab38_0242ac130202row1_col3,#T_b6b61cbc_771e_11eb_ab38_0242ac130202row8_col4,#T_b6b61cbc_771e_11eb_ab38_0242ac130202row29_col3,#T_b6b61cbc_771e_11eb_ab38_0242ac130202row29_col9{
#             background-color:  #ff00ff;
#             color:  #f1f1f1;
#         }#T_b6b61cbc_771e_11eb_ab38_0242ac130202row1_col4,#T_b6b61cbc_771e_11eb_ab38_0242ac130202row18_col9,#T_b6b61cbc_771e_11eb_ab38_0242ac130202row19_col9,#T_b6b61cbc_771e_11eb_ab38_0242ac130202row20_col9{
#             background-color:  #ff0af5;
#             color:  #f1f1f1;
#         }#T_b6b61cbc_771e_11eb_ab38_0242ac130202row1_col9{
#             background-color:  #ff916e;
#             color:  #000000;
#         }#T_b6b61cbc_771e_11eb_ab38_0242ac130202row2_col3,#T_b6b61cbc_771e_11eb_ab38_0242ac130202row7_col3,#T_b6b61cbc_771e_11eb_ab38_0242ac130202row12_col3,#T_b6b61cbc_771e_11eb_ab38_0242ac130202row13_col3,#T_b6b61cbc_771e_11eb_ab38_0242ac130202row20_col3{
#             background-color:  #ff807f;
#             color:  #000000;
#         }#T_b6b61cbc_771e_11eb_ab38_0242ac130202row2_col4{
#             background-color:  #ff0ef1;
#             color:  #f1f1f1;
#         }#T_b6b61cbc_771e_11eb_ab38_0242ac130202row2_col9{
#             background-color:  #ff5aa5;
#             color:  #000000;
#         }#T_b6b61cbc_771e_11eb_ab38_0242ac130202row3_col4,#T_b6b61cbc_771e_11eb_ab38_0242ac130202row6_col9,#T_b6b61cbc_771e_11eb_ab38_0242ac130202row12_col4{
#             background-color:  #ff3fc0;
#             color:  #000000;
#         }#T_b6b61cbc_771e_11eb_ab38_0242ac130202row3_col9{
#             background-color:  #ff52ad;
#             color:  #000000;
#         }#T_b6b61cbc_771e_11eb_ab38_0242ac130202row4_col3,#T_b6b61cbc_771e_11eb_ab38_0242ac130202row9_col3,#T_b6b61cbc_771e_11eb_ab38_0242ac130202row18_col3,#T_b6b61cbc_771e_11eb_ab38_0242ac130202row19_col3,#T_b6b61cbc_771e_11eb_ab38_0242ac130202row21_col3,#T_b6b61cbc_771e_11eb_ab38_0242ac130202row22_col3,#T_b6b61cbc_771e_11eb_ab38_0242ac130202row26_col3{
#             background-color:  #ffe01f;
#             color:  #000000;
#         }#T_b6b61cbc_771e_11eb_ab38_0242ac130202row4_col4{
#             background-color:  #ff45ba;
#             color:  #000000;
#         }#T_b6b61cbc_771e_11eb_ab38_0242ac130202row4_col9{
#             background-color:  #ff49b6;
#             color:  #000000;
#         }#T_b6b61cbc_771e_11eb_ab38_0242ac130202row5_col4{
#             background-color:  #ff28d7;
#             color:  #f1f1f1;
#         }#T_b6b61cbc_771e_11eb_ab38_0242ac130202row5_col9{
#             background-color:  #ff47b8;
#             color:  #000000;
#         }#T_b6b61cbc_771e_11eb_ab38_0242ac130202row6_col3{
#             background-color:  #ff609f;
#             color:  #000000;
#         }#T_b6b61cbc_771e_11eb_ab38_0242ac130202row6_col4{
#             background-color:  #ff01fe;
#             color:  #f1f1f1;
#         }#T_b6b61cbc_771e_11eb_ab38_0242ac130202row7_col9{
#             background-color:  #ff31ce;
#             color:  #f1f1f1;
#         }#T_b6b61cbc_771e_11eb_ab38_0242ac130202row8_col9,#T_b6b61cbc_771e_11eb_ab38_0242ac130202row14_col4{
#             background-color:  #ff2ed1;
#             color:  #f1f1f1;
#         }#T_b6b61cbc_771e_11eb_ab38_0242ac130202row9_col4,#T_b6b61cbc_771e_11eb_ab38_0242ac130202row21_col9{
#             background-color:  #ff09f6;
#             color:  #f1f1f1;
#         }#T_b6b61cbc_771e_11eb_ab38_0242ac130202row9_col9,#T_b6b61cbc_771e_11eb_ab38_0242ac130202row10_col9,#T_b6b61cbc_771e_11eb_ab38_0242ac130202row23_col4,#T_b6b61cbc_771e_11eb_ab38_0242ac130202row25_col4{
#             background-color:  #ff21de;
#             color:  #f1f1f1;
#         }#T_b6b61cbc_771e_11eb_ab38_0242ac130202row10_col3,#T_b6b61cbc_771e_11eb_ab38_0242ac130202row28_col3{
#             background-color:  #ffa05f;
#             color:  #000000;
#         }#T_b6b61cbc_771e_11eb_ab38_0242ac130202row10_col4{
#             background-color:  #ff19e6;
#             color:  #f1f1f1;
#         }#T_b6b61cbc_771e_11eb_ab38_0242ac130202row11_col4{
#             background-color:  #ff12ed;
#             color:  #f1f1f1;
#         }#T_b6b61cbc_771e_11eb_ab38_0242ac130202row11_col9,#T_b6b61cbc_771e_11eb_ab38_0242ac130202row24_col3{
#             background-color:  #ff20df;
#             color:  #f1f1f1;
#         }#T_b6b61cbc_771e_11eb_ab38_0242ac130202row12_col9,#T_b6b61cbc_771e_11eb_ab38_0242ac130202row13_col9,#T_b6b61cbc_771e_11eb_ab38_0242ac130202row14_col9,#T_b6b61cbc_771e_11eb_ab38_0242ac130202row15_col9{
#             background-color:  #ff16e9;
#             color:  #f1f1f1;
#         }#T_b6b61cbc_771e_11eb_ab38_0242ac130202row13_col4{
#             background-color:  #ff3dc2;
#             color:  #000000;
#         }#T_b6b61cbc_771e_11eb_ab38_0242ac130202row14_col3,#T_b6b61cbc_771e_11eb_ab38_0242ac130202row17_col3{
#             background-color:  #ff40bf;
#             color:  #000000;
#         }#T_b6b61cbc_771e_11eb_ab38_0242ac130202row15_col4{
#             background-color:  #ff15ea;
#             color:  #f1f1f1;
#         }#T_b6b61cbc_771e_11eb_ab38_0242ac130202row16_col4{
#             background-color:  #ff0bf4;
#             color:  #f1f1f1;
#         }#T_b6b61cbc_771e_11eb_ab38_0242ac130202row16_col9{
#             background-color:  #ff10ef;
#             color:  #f1f1f1;
#         }#T_b6b61cbc_771e_11eb_ab38_0242ac130202row17_col4{
#             background-color:  #ff5ba4;
#             color:  #000000;
#         }#T_b6b61cbc_771e_11eb_ab38_0242ac130202row17_col9{
#             background-color:  #ff0df2;
#             color:  #f1f1f1;
#         }#T_b6b61cbc_771e_11eb_ab38_0242ac130202row18_col4{
#             background-color:  #ff35ca;
#             color:  #000000;
#         }#T_b6b61cbc_771e_11eb_ab38_0242ac130202row19_col4{
#             background-color:  #ff659a;
#             color:  #000000;
#         }#T_b6b61cbc_771e_11eb_ab38_0242ac130202row20_col4{
#             background-color:  #ff619e;
#             color:  #000000;
#         }#T_b6b61cbc_771e_11eb_ab38_0242ac130202row21_col4{
#             background-color:  #ff17e8;
#             color:  #f1f1f1;
#         }#T_b6b61cbc_771e_11eb_ab38_0242ac130202row22_col4{
#             background-color:  #ff33cc;
#             color:  #000000;
#         }#T_b6b61cbc_771e_11eb_ab38_0242ac130202row22_col9,#T_b6b61cbc_771e_11eb_ab38_0242ac130202row23_col9,#T_b6b61cbc_771e_11eb_ab38_0242ac130202row24_col9{
#             background-color:  #ff08f7;
#             color:  #f1f1f1;
#         }#T_b6b61cbc_771e_11eb_ab38_0242ac130202row24_col4{
#             background-color:  #ffad52;
#             color:  #000000;
#         }#T_b6b61cbc_771e_11eb_ab38_0242ac130202row25_col9{
#             background-color:  #ff06f9;
#             color:  #f1f1f1;
#         }#T_b6b61cbc_771e_11eb_ab38_0242ac130202row26_col4{
#             background-color:  #ff2fd0;
#             color:  #f1f1f1;
#         }#T_b6b61cbc_771e_11eb_ab38_0242ac130202row26_col9{
#             background-color:  #ff05fa;
#             color:  #f1f1f1;
#         }#T_b6b61cbc_771e_11eb_ab38_0242ac130202row27_col4{
#             background-color:  #ff9a65;
#             color:  #000000;
#         }#T_b6b61cbc_771e_11eb_ab38_0242ac130202row27_col9,#T_b6b61cbc_771e_11eb_ab38_0242ac130202row28_col9{
#             background-color:  #ff02fd;

# %% [markdown]
# # Transmission : Manual

# %%
display(train[train["Transmission"]=="Manual"][["Name","Location","Transmission","Year","Kilometers_Driven","Fuel_Type","Mileage","Engine","Power",
                                       "Price"]].sort_values(by="Price", ascending= False).head(30).style.background_gradient(cmap="spring"))
# Out:
# <style  type="text/css" >
# #T_b6ded6c0_771e_11eb_ab38_0242ac130202row0_col3,#T_b6ded6c0_771e_11eb_ab38_0242ac130202row12_col4,#T_b6ded6c0_771e_11eb_ab38_0242ac130202row29_col9{
#             background-color:  #ff00ff;
#             color:  #f1f1f1;
#         }#T_b6ded6c0_771e_11eb_ab38_0242ac130202row0_col4{
#             background-color:  #ff6f90;
#             color:  #000000;
#         }#T_b6ded6c0_771e_11eb_ab38_0242ac130202row0_col9,#T_b6ded6c0_771e_11eb_ab38_0242ac130202row2_col3,#T_b6ded6c0_771e_11eb_ab38_0242ac130202row8_col3,#T_b6ded6c0_771e_11eb_ab38_0242ac130202row12_col3,#T_b6ded6c0_771e_11eb_ab38_0242ac130202row18_col4,#T_b6ded6c0_771e_11eb_ab38_0242ac130202row19_col3,#T_b6ded6c0_771e_11eb_ab38_0242ac130202row20_col3,#T_b6ded6c0_771e_11eb_ab38_0242ac130202row23_col3{
#             background-color:  #ffff00;
#             color:  #000000;
#         }#T_b6ded6c0_771e_11eb_ab38_0242ac130202row1_col3{
#             background-color:  #ff2ed1;
#             color:  #f1f1f1;
#         }#T_b6ded6c0_771e_11eb_ab38_0242ac130202row1_col4,#T_b6ded6c0_771e_11eb_ab38_0242ac130202row24_col9,#T_b6ded6c0_771e_11eb_ab38_0242ac130202row25_col9,#T_b6ded6c0_771e_11eb_ab38_0242ac130202row26_col9{
#             background-color:  #ff06f9;
#             color:  #f1f1f1;
#         }#T_b6ded6c0_771e_11eb_ab38_0242ac130202row1_col9{
#             background-color:  #fff50a;
#             color:  #000000;
#         }#T_b6ded6c0_771e_11eb_ab38_0242ac130202row2_col4{
#             background-color:  #ff58a7;
#             color:  #000000;
#         }#T_b6ded6c0_771e_11eb_ab38_0242ac130202row2_col9{
#             background-color:  #ffc13e;
#             color:  #000000;
#         }#T_b6ded6c0_771e_11eb_ab38_0242ac130202row3_col3,#T_b6ded6c0_771e_11eb_ab38_0242ac130202row6_col3,#T_b6ded6c0_771e_11eb_ab38_0242ac130202row7_col3,#T_b6ded6c0_771e_11eb_ab38_0242ac130202row13_col3,#T_b6ded6c0_771e_11eb_ab38_0242ac130202row27_col3{
#             background-color:  #ffd12e;
#             color:  #000000;
#         }#T_b6ded6c0_771e_11eb_ab38_0242ac130202row3_col4,#T_b6ded6c0_771e_11eb_ab38_0242ac130202row28_col9{
#             background-color:  #ff03fc;
#             color:  #f1f1f1;
#         }#T_b6ded6c0_771e_11eb_ab38_0242ac130202row3_col9{
#             background-color:  #ffb748;
#             color:  #000000;
#         }#T_b6ded6c0_771e_11eb_ab38_0242ac130202row4_col3,#T_b6ded6c0_771e_11eb_ab38_0242ac130202row22_col3{
#             background-color:  #ffe817;
#             color:  #000000;
#         }#T_b6ded6c0_771e_11eb_ab38_0242ac130202row4_col4{
#             background-color:  #ff3bc4;
#             color:  #000000;
#         }#T_b6ded6c0_771e_11eb_ab38_0242ac130202row4_col9{
#             background-color:  #ff946b;
#             color:  #000000;
#         }#T_b6ded6c0_771e_11eb_ab38_0242ac130202row5_col3,#T_b6ded6c0_771e_11eb_ab38_0242ac130202row15_col3,#T_b6ded6c0_771e_11eb_ab38_0242ac130202row25_col3,#T_b6ded6c0_771e_11eb_ab38_0242ac130202row28_col3,#T_b6ded6c0_771e_11eb_ab38_0242ac130202row29_col3{
#             background-color:  #ffba45;
#             color:  #000000;
#         }#T_b6ded6c0_771e_11eb_ab38_0242ac130202row5_col4{
#             background-color:  #ff34cb;
#             color:  #000000;
#         }#T_b6ded6c0_771e_11eb_ab38_0242ac130202row5_col9{
#             background-color:  #ff7f80;
#             color:  #000000;
#         }#T_b6ded6c0_771e_11eb_ab38_0242ac130202row6_col4{
#             background-color:  #ff758a;
#             color:  #000000;
#         }#T_b6ded6c0_771e_11eb_ab38_0242ac130202row6_col9{
#             background-color:  #ff6c93;
#             color:  #000000;
#         }#T_b6ded6c0_771e_11eb_ab38_0242ac130202row7_col4{
#             background-color:  #ff48b7;
#             color:  #000000;
#         }#T_b6ded6c0_771e_11eb_ab38_0242ac130202row7_col9{
#             background-color:  #ff6798;
#             color:  #000000;
#         }#T_b6ded6c0_771e_11eb_ab38_0242ac130202row8_col4{
#             background-color:  #ff0ef1;
#             color:  #f1f1f1;
#         }#T_b6ded6c0_771e_11eb_ab38_0242ac130202row8_col9{
#             background-color:  #ff5aa5;
#             color:  #000000;
#         }#T_b6ded6c0_771e_11eb_ab38_0242ac130202row9_col3,#T_b6ded6c0_771e_11eb_ab38_0242ac130202row14_col3,#T_b6ded6c0_771e_11eb_ab38_0242ac130202row17_col3,#T_b6ded6c0_771e_11eb_ab38_0242ac130202row24_col3{
#             background-color:  #ff8b74;
#             color:  #000000;
#         }#T_b6ded6c0_771e_11eb_ab38_0242ac130202row9_col4{
#             background-color:  #ff21de;
#             color:  #f1f1f1;
#         }#T_b6ded6c0_771e_11eb_ab38_0242ac130202row9_col9,#T_b6ded6c0_771e_11eb_ab38_0242ac130202row10_col9{
#             background-color:  #ff49b6;
#             color:  #000000;
#         }#T_b6ded6c0_771e_11eb_ab38_0242ac130202row10_col3,#T_b6ded6c0_771e_11eb_ab38_0242ac130202row11_col3,#T_b6ded6c0_771e_11eb_ab38_0242ac130202row16_col3,#T_b6ded6c0_771e_11eb_ab38_0242ac130202row18_col3,#T_b6ded6c0_771e_11eb_ab38_0242ac130202row21_col3,#T_b6ded6c0_771e_11eb_ab38_0242ac130202row26_col3{
#             background-color:  #ffa25d;
#             color:  #000000;
#         }#T_b6ded6c0_771e_11eb_ab38_0242ac130202row10_col4{
#             background-color:  #ff23dc;
#             color:  #f1f1f1;
#         }#T_b6ded6c0_771e_11eb_ab38_0242ac130202row11_col4{
#             background-color:  #ff17e8;
#             color:  #f1f1f1;
#         }#T_b6ded6c0_771e_11eb_ab38_0242ac130202row11_col9{
#             background-color:  #ff37c8;
#             color:  #000000;
#         }#T_b6ded6c0_771e_11eb_ab38_0242ac130202row12_col9,#T_b6ded6c0_771e_11eb_ab38_0242ac130202row13_col9{
#             background-color:  #ff2fd0;
#             color:  #f1f1f1;
#         }#T_b6ded6c0_771e_11eb_ab38_0242ac130202row13_col4{
#             background-color:  #ff39c6;
#             color:  #000000;
#         }#T_b6ded6c0_771e_11eb_ab38_0242ac130202row14_col4{
#             background-color:  #ff936c;
#             color:  #000000;
#         }#T_b6ded6c0_771e_11eb_ab38_0242ac130202row14_col9,#T_b6ded6c0_771e_11eb_ab38_0242ac130202row23_col4{
#             background-color:  #ff2cd3;
#             color:  #f1f1f1;
#         }#T_b6ded6c0_771e_11eb_ab38_0242ac130202row15_col4{
#             background-color:  #ffa55a;
#             color:  #000000;
#         }#T_b6ded6c0_771e_11eb_ab38_0242ac130202row15_col9{
#             background-color:  #ff2ad5;
#             color:  #f1f1f1;
#         }#T_b6ded6c0_771e_11eb_ab38_0242ac130202row16_col4{
#             background-color:  #ff5da2;
#             color:  #000000;
#         }#T_b6ded6c0_771e_11eb_ab38_0242ac130202row16_col9,#T_b6ded6c0_771e_11eb_ab38_0242ac130202row17_col9,#T_b6ded6c0_771e_11eb_ab38_0242ac130202row18_col9{
#             background-color:  #ff24db;
#             color:  #f1f1f1;
#         }#T_b6ded6c0_771e_11eb_ab38_0242ac130202row17_col4{
#             background-color:  #ff44bb;
#             color:  #000000;
#         }#T_b6ded6c0_771e_11eb_ab38_0242ac130202row19_col4{
#             background-color:  #ff08f7;
#             color:  #f1f1f1;
#         }#T_b6ded6c0_771e_11eb_ab38_0242ac130202row19_col9{
#             background-color:  #ff1fe0;
#             color:  #f1f1f1;
#         }#T_b6ded6c0_771e_11eb_ab38_0242ac130202row20_col4{
#             background-color:  #ff30cf;
#             color:  #f1f1f1;
#         }#T_b6ded6c0_771e_11eb_ab38_0242ac130202row20_col9{
#             background-color:  #ff1ae5;
#             color:  #f1f1f1;
#         }#T_b6ded6c0_771e_11eb_ab38_0242ac130202row21_col4{
#             background-color:  #ff7788;
#             color:  #000000;
#         }#T_b6ded6c0_771e_11eb_ab38_0242ac130202row21_col9{
#             background-color:  #ff18e7;
#             color:  #f1f1f1;
#         }#T_b6ded6c0_771e_11eb_ab38_0242ac130202row22_col4,#T_b6ded6c0_771e_11eb_ab38_0242ac130202row28_col4{
#             background-color:  #ff4ab5;
#             color:  #000000;
#         }#T_b6ded6c0_771e_11eb_ab38_0242ac130202row22_col9{
#             background-color:  #ff14eb;
#             color:  #f1f1f1;
#         }#T_b6ded6c0_771e_11eb_ab38_0242ac130202row23_col9{
#             background-color:  #ff11ee;
#             color:  #f1f1f1;
#         }#T_b6ded6c0_

# %%
test= pd.read_csv('../input/used-cars-price-prediction/test-data.csv')
test.head()
# Out:
#    Unnamed: 0                                       Name    Location  Year  \
# 0           0                    Maruti Alto K10 LXI CNG       Delhi  2014
# 1           1              Maruti Alto 800 2016-2019 LXI  Coimbatore  2013
# 2           2  Toyota Innova Crysta Touring Sport 2.4 MT      Mumbai  2017
# 3           3                       Toyota Etios Liva GD   Hyderabad  2012
# 4           4                          Hyundai i20 Magna      Mumbai  2014
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type      Mileage   Engine  \
# 0              40929       CNG       Manual      First  32.26 km/kg   998 CC
# 1              54493    Petrol       Manual     Second    24.7 kmpl   796 CC
# 2              34000    Diesel       Manual      First   13.68 kmpl  2393 CC
# 3             139000    Diesel       Manual      First   23.59 kmpl  1364 CC
# 4              29000    Petrol       Manual      First    18.5 kmpl  1197 CC
#
#        Power  Seats   New_Price
# 0   58.2 bhp    4.0         NaN
# 1   47.3 bhp    5.0         NaN
# 2  147.8 bhp    7.0  25.27 Lakh
# 3   null bhp    5.0         NaN
# 4  82.85 bhp    5.0         NaN

# %% [markdown]
# # Prepocessing

# %%
labels = {}
for col in train.select_dtypes(exclude = np.number).columns.tolist():
    le = LabelEncoder().fit(pd.concat([train[col].astype(str),test[col].astype(str)]))   
    train[col] = le.transform(train[col].astype(str))
    test[col] = le.transform(test[col].astype(str))
    labels [col] = le
print('Categorical columns:', list(labels.keys()))
# Out:
# Categorical columns: ['Name', 'Location', 'Fuel_Type', 'Transmission', 'Owner_Type', 'Mileage', 'Engine', 'Power', 'New_Price']

# %% [markdown]
# # Check Missing Data

# %%
print(f'Percent of Nans in Train Data : {round(train.isna().sum().sum()/len(train), 2)}')
print(f'Percent of Nans in Test  Data : {round(test.isna().sum().sum()/len(test), 2)}')
# Out:
# Percent of Nans in Train Data : 0.01
# Percent of Nans in Test  Data : 0.01

# %%
train = train.replace([np.inf, -np.inf], np.nan)
train= train.fillna(train.mean())
train
# Out:
#       Unnamed: 0  Name  Location  Year  Kilometers_Driven  Fuel_Type  \
# 0              0  1310         9  2010              72000          0
# 1              1   560        10  2015              41000          1
# 2              2   529         2  2011              46000          4
# 3              3  1160         2  2012              87000          1
# 4              4    23         3  2013              40670          1
# ...          ...   ...       ...   ...                ...        ...
# 6014        6014  1265         4  2014              27365          1
# 6015        6015   732         6  2015             100000          1
# 6016        6016  1025         6  2012              55000          1
# 6017        6017  1317         8  2013              46000          4
# 6018        6018   173         5  2011              47000          1
#
#       Transmission  Owner_Type  Mileage  Engine  Power  Seats  New_Price  \
# 0                1           0      411     148    271    5.0        625
# 1                1           0      282      40     57    5.0        625
# 2                1           0      239      12    357    5.0        557
# 3                1           0      315      14    359    7.0        625
# 4                0           2      140      60     78    5.0        625
# ...            ...         ...      ...     ...    ...    ...        ...
# 6014             1           0      421      14    311    5.0        513
# 6015             1           0      385       3    302    5.0        625
# 6016             1           2       95      96     30    8.0        625
# 6017             1           0      260     148    294    5.0        625
# 6018             1           0      399     144    270    5.0        625
#
#       Price
# 0      1.75
# 1     12.50
# 2      4.50
# 3      6.00
# 4     17.74
# ...     ...
# 6014   4.75
# 6015   4.00
# 6016   2.90
# 6017   2.65
# 6018   2.50
#
# [6019 rows x 14 columns]

# %%
test = test.replace([np.inf, -np.inf], np.nan)
test= test.fillna(test.mean())
test
# Out:
#       Unnamed: 0  Name  Location  Year  Kilometers_Driven  Fuel_Type  \
# 0              0  1059         4  2014              40929          0
# 1              1  1049         3  2013              54493          4
# 2              2  1935         9  2017              34000          1
# 3              3  1870         5  2012             139000          1
# 4              4   827         9  2014              29000          4
# ...          ...   ...       ...   ...                ...        ...
# 1229        1229  2013         5  2011              89411          1
# 1230        1230  1988         9  2015              59000          4
# 1231        1231  1499         8  2012              28000          1
# 1232        1232  1988        10  2013              52262          4
# 1233        1233  1366         7  2014              72443          1
#
#       Transmission  Owner_Type  Mileage  Engine  Power  Seats  New_Price
# 0                1           0      424     148    272    4.0        625
# 1                1           2      389     141    252    5.0        625
# 2                1           0       89      86     88    7.0        237
# 3                1           0      375      19    386    5.0        625
# 4                1           0      248      10    334    5.0        625
# ...            ...         ...      ...     ...    ...    ...        ...
# 1229             1           0      306      47     13    5.0        625
# 1230             0           0      205      10     13    5.0        625
# 1231             1           0      367      30    280    5.0        625
# 1232             0           3      204      10     13    5.0        625
# 1233             0           0        1      75    123    5.0        625
#
# [1234 rows x 13 columns]

# %% [markdown]
# Eliminate irrelevant variables in analysis such as New_Price.

# %%
train = train.drop(columns=['New_Price'],
                 axis=1)
train = train.dropna(how='any')
print(train.shape)
# Out:
# (6019, 13)

# %%
test= test.drop(columns=['New_Price'],

                 axis=1)
test = test.dropna(how='any')
print(test.shape)
# Out:
# (1234, 12)

# %%
#Select feature column names and target variable we are going to use for training

features =['Name','Location','Year','Kilometers_Driven','Fuel_Type','Transmission','Owner_Type','Mileage','Engine','Power','Seats']
target = 'Price'

# %%
#This is input which our classifier will use as an input.
train[features].head(10)
# Out:
#    Name  Location  Year  Kilometers_Driven  Fuel_Type  Transmission  \
# 0  1310         9  2010              72000          0             1
# 1   560        10  2015              41000          1             1
# 2   529         2  2011              46000          4             1
# 3  1160         2  2012              87000          1             1
# 4    23         3  2013              40670          1             0
# 5   583         5  2012              75000          3             1
# 6  1499         6  2013              86999          1             1
# 7  1933         9  2016              36000          1             0
# 8  2011        10  2013              64430          1             1
# 9  1720         2  2012              65932          1             1
#
#    Owner_Type  Mileage  Engine  Power  Seats
# 0           0      411     148    271    5.0
# 1           0      282      40     57    5.0
# 2           0      239      12    357    5.0
# 3           0      315      14    359    7.0
# 4           2      140      60     78    5.0
# 5           0      324     143    263    5.0
# 6           0      367      30    280    5.0
# 7           0       23     105    126    8.0
# 8           0      306      47     13    5.0
# 9           2      351      14    311    5.0

# %%
#This is input which our classifier will use as an input.
test[features].head(10)
# Out:
#    Name  Location  Year  Kilometers_Driven  Fuel_Type  Transmission  \
# 0  1059         4  2014              40929          0             1
# 1  1049         3  2013              54493          4             1
# 2  1935         9  2017              34000          1             1
# 3  1870         5  2012             139000          1             1
# 4   827         9  2014              29000          4             1
# 5  1017         3  2016              85609          1             1
# 6  1886        10  2015              59000          1             0
# 7   582         6  2013              65000          4             1
# 8   457         9  2011              66000          4             1
# 9  1014         3  2015              54684          1             1
#
#    Owner_Type  Mileage  Engine  Power  Seats
# 0           0      424     148    272    4.0
# 1           2      389     141    252    5.0
# 2           0       89      86     88    7.0
# 3           0      375      19    386    5.0
# 4           0      248      10    334    5.0
# 5           2      162      77     77    7.0
# 6           0       53     115    121    7.0
# 7           0      325     143    263    5.0
# 8           2      194      37     42    5.0
# 9           0      136      77     77    7.0

# %% [markdown]
# # Model

# %% [markdown]
# ## Data for training and validation (Measure MSE)
#
# To select a set of training data that will be input in the Machine Learning algorithm, to ensure that the classification algorithm training can be generalized well to new data. For this study using a sample size of 15%, assumed it ideal ratio between training and validation

# %%
from sklearn.model_selection import train_test_split
Y = train['Price']
X = train.drop(columns=['Price'])
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.15, random_state=9)

print('X train shape: ', X_train.shape)
print('Y train shape: ', Y_train.shape)
print('X test shape: ', X_test.shape)
print('Y test shape: ', Y_test.shape)
# Out:
# X train shape:  (5116, 12)
# Y train shape:  (5116,)
# X test shape:  (903, 12)
# Y test shape:  (903,)

# %% [markdown]
# # GridSearchCV: RandomForestRegressor
#
# <img src='https://media.geeksforgeeks.org/wp-content/uploads/20200516180708/Capture482.png' width='400'>
#
#
#
# * GridSearchCV is a library function that is a member of sklearn's model_selection package. It helps to loop through predefined hyperparameters and fit your estimator (model) on your training set. So, in the end, you can select the best parameters from the listed hyperparameters. Reference : https://towardsdatascience.com/grid-search-for-hyperparameter-tuning-9f63945e8fec#:~:text=What%20is%20GridSearchCV%3F,parameters%20from%20the%20listed%20hyperparameters.
#
# * A Random Forest is an ensemble technique capable of performing both regression and classification tasks with the use of multiple decision trees and a technique called Bootstrap and Aggregation, commonly known as bagging. The basic idea behind this is to combine multiple decision trees in determining the final output rather than relying on individual decision trees. Random Forest has multiple decision trees as base learning models. We randomly perform row sampling and feature sampling from the dataset forming sample datasets for every model. This part is called Bootstrap.
# Reference : https://www.geeksforgeeks.org/random-forest-regression-in-python/

# %% [markdown]
# # Model 1

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score,mean_squared_error
from sklearn.metrics import mean_absolute_error 
# We define the model
estimator = RandomForestRegressor(random_state = 42,criterion='mse')
para_grids = {
            "n_estimators" : [10,50,100],
            "max_features" : ["auto", "log2", "sqrt"],
            'max_depth' : [4,5,6,7,8,9,15],
            "bootstrap"    : [True, False]
        }


Grid = GridSearchCV(estimator, para_grids,cv= 5)
# We train model
Grid.fit(X_train, Y_train)
best_param = Grid.best_estimator_
print(best_param)
# Out:
# RandomForestRegressor(bootstrap=False, max_depth
#         4.82236028,  3.05234573,  5.39005983, 26.13989977, 29.03329771,
#        42.1594716 , 11.10095556, 11.27939658,  2.09905655,  2.16325243,
#         9.43933808,  5.83471818,  7.75197889,  6.1739523 ,  3.54532311,
#         5.39027225,  7.22668586,  6.3949621 ,  2.7716754 ,  2.52961457,
#        22.77206948,  2.86658191,  1.75199566,  1.23660501,  4.36411438,
#         1.30299143,  5.20285523,  5.65173114,  6.25724182,  4.15016173,
#        12.99112366,  2.98630091,  5.68009474,  5.39053063, 22.03353229,
#         3.65421752,  3.47869824,  5.62722904,  5.96197227,  1.69928108,
#         3.31569891, 14.66681315, 30.72608631,  5.13154053, 23.75132652,
#         2.92319333,  2.87121855,  4.94044663,  2.68479425, 21.26655411,
#         5.34991686,  0.59455083,  3.51412422,  7.30231913,  2.90887317,
#        16.38568186,  6.19498612,  2.90698952,  4.92176155, 13.57527498,
#         2.73267019,  3.2842162 ,  9.80755998,  3.0244385 ,  7.86072422,
#         3.98612341,  3.43761808, 12.87369812, 19.49865763, 10.88534505,
#         5.07652973, 18.00390833,  6.30430003,  4.80195198,  3.95812154,
#         1.64796391, 19.7192268 ,  6.107793  ,  7.28860727,  1.8603348 ,
#         4.46807104,  6.67643193, 32.50679062])

# %% [markdown]
# # Model 2

# %%
model = RandomForestRegressor(bootstrap=False, max_depth=15, max_features='log2',
                      random_state=42)
# We train model
model.fit(train[features],train[target])
# Out:
# RandomForestRegressor(bootstrap=False, max_depth=15, max_features='log2',
#                       random_state=42)

# %% [markdown]
# ## prediction

# %%
#Make predictions using the features from the test data set
predictions = model.predict(test[features])

# %% [markdown]
# # Model 3
#
# k-fold is a popular kind of cross-validation technique, in which, say k=10 for example, 9 folds for training and 1 fold for testing purpose and this repeats unless all folds get a chance to be the test set one by one. This way, it provides a good idea of the generalization ability of the model, especially when we have limited data and can't afford to split into test and training data.
#
# Reference :https://www.researchgate.net/post/What-is-the-purpose-of-performing-cross-validation

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from numpy import mean, std

cv = KFold(n_splits=10, random_state=1, shuffle=True)
scores = cross_val_score(model, train[features], train[target], cv=cv, n_jobs=-1)
print('Mean of Scores: %.3f' % (mean(scores)))
# Out:
# Mean of Scores: 0.905

# %% [markdown]
# # Measure mean squared error
#
# In statistics, the mean squared error (MSE) or mean squared deviation (MSD) of an estimator (of a procedure for estimating an unobserved quantity) measures the average of the squares of the errors—that is, the average squared difference between the estimated values and the actual value.
#
# Reference : https://en.wikipedia.org/wiki/Mean_squared_error

# %%
#Model 1
from sklearn.metrics import mean_squared_error
mean_squared_error(Y_test, Y_predict)
# Out:
# 13.501790650710793

# %% [markdown]
# # Make Submission

# %%
#Create a  DataFrame
submission = pd.DataFrame({'Owner_Type':test['Owner_Type'],'Price':predictions})                        

#Visualize the first 10 rows
submission.head(10)
# Out:
#    Owner_Type      Price
# 0           0   4.790472
# 1           2   2.576309
# 2           0  17.990767
# 3           0   3.528249
# 4           0   4.436009
# 5           2  11.107298
# 6           0  20.440234
# 7           0   2.746336
# 8           2   3.893432
# 9           0  10.805169

# %%
#Convert DataFrame to a csv file that can be uploaded
#This is saved in the same directory as your notebook
filename = 'submission.csv'

submission.to_csv(filename,index=True)

print('Saved file: ' + filename)
# Out:
# Saved file: submission.csv
